# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       Age     Sex     BMI  Children Smoker      Charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       Age     BMI  Children      Charges  Sex_male  Smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['Age', 'BMI', 'Children','Sex_male', 'Smoker_yes']]
dep=dataset['Charges']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error'],
'max_features': ['auto','sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.099977      0.007652         0.003125        0.006250
# 1        0.843210      0.010000         0.028120        0.006245
# 2        0.071857      0.007651         0.003124        0.006249
# 3        0.637684      0.013790         0.031244        0.009879
# 4        0.065609      0.006249         0.003125        0.006249
# 5        0.643273      0.008707         0.021871        0.007653
# 6        0.362261      0.011594         0.000000        0.000000
# 7        3.407047      0.020046         0.021871        0.007653
# 8        0.207007      0.007669         0.013367        0.005660
# 9        2.033895      0.032754         0.023369        0.006987
# 10       0.215958      0.006483         0.006249        0.007653
# 11       1.908944      0.149359         0.021871        0.007652
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.833597
# 1   {'criterion': 'squared_error', 'max_features':...           0.843261
# 2   {'criterion': 'squared_error', 'max_features':...           0.842330
# 3   {'criterion': 'squared_error', 'max_features':...           0.857836
# 4   {'criterion': 'squared_error', 'max_features':...           0.844590
# 5   {'criterion': 'squared_error', 'max_features':...           0.855269
# 6   {'criterion': 'absolute_error', 'max_features'...           0.844079
# 7   {'criterion': 'absolute_error', 'max_features'...           0.836437
# 8   {'criterion': 'absolute_error', 'max_features'...           0.842784
# 9   {'criterion': 'absolute_error', 'max_features'...           0.857500
# 10  {'criterion': 'absolute_error', 'max_features'...           0.820379
# 11  {'criterion': 'absolute_error', 'max_features'...           0.855286
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.752378           0.847059           0.820292
# 1            0.771476           0.861654           0.819823
# 2            0.771032           0.829259           0.810830
# 3            0.780362           0.860209           0.825514
# 4            0.766563           0.849226           0.814448
# 5            0.777443           0.863558           0.830460
# 6            0.750150           0.819243           0.810911
# 7            0.770111           0.847515           0.823313
# 8            0.763505           0.829448           0.812504
# 9            0.782656           0.858754           0.829926
# 10           0.772806           0.842146           0.814519
# 11           0.778745           0.861517           0.828652
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.840549         0.818775        0.034365                9
# 1            0.836062         0.826455        0.030595                5
# 2            0.828786         0.816447        0.024821               11
# 3            0.838807         0.832546        0.029040                4
# 4            0.830340         0.821033        0.029822                7
# 5            0.842574         0.833861        0.030367                3
# 6            0.822714         0.809420        0.031590               12
# 7            0.837760         0.823027        0.027556                6
# 8            0.835261         0.816701        0.028407               10
# 9            0.842116         0.834190        0.027869                1
# 10           0.850568         0.820084        0.027138                8
# 11           0.846676         0.834175        0.029841                2

# %%
Age_input=float(input("Age:"))
BMI_input=float(input("BMI:"))
Children_input=float(input("Children:"))
Sex_male_input=int(input("Sex Male 0 or 1:"))
Smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 20
# BMI: 20
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[Age_input,BMI_input,Children_input,Sex_male_input,Smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16620.5815886]
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
