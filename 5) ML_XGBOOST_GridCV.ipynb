# %%
#pip install to xgboost
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\dell\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from xgboost) (1.11.4)

# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#reads dataset using pandas function
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
#shows the input dataset
# Out:
#       Age     Sex     BMI  Children Smoker      Charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Due to Nominal data present in dataset (i.e) State, Use get_dummies to split (One hot encoding)
#drop_first is used to eliminate 1st column of state as the result will be same even it is dropped and memory consuming is less
dataset = pd.get_dummies(dataset,dtype=int, drop_first = True)
#shows the input dataset
dataset
# Out:
#       Age     BMI  Children      Charges  Sex_male  Smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
#for viewing all columns of dataset
# Out:
# Index(['Age', 'BMI', 'Children', 'Charges', 'Sex_male', 'Smoker_yes'], dtype='object')

# %%
indep=dataset[['Age', 'BMI', 'Children','Sex_male', 'Smoker_yes']]
dep=dataset['Charges']

# %%
#Using XGBoostregressor algorithm function
from sklearn.model_selection import GridSearchCV
import xgboost
from xgboost import XGBRegressor
param_grid = {'objective': ['reg:linear'],'n_estimators': [10,20,30],'seed':[10,20,30]}
grid = GridSearchCV(XGBRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# C:\Users\DELL\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [23:23:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'n_estimators': [10, 20, 30],
#                          'objective': ['reg:linear'], 'seed': [10, 20, 30]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'n_estimators': 10, 'objective': 'reg:linear', 'seed': 10}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.035667      0.004924         0.002916        0.003611
# 1       0.022943      0.005950         0.007173        0.008905
# 2       0.028187      0.007529         0.007703        0.002548
# 3       0.040660      0.004251         0.002749        0.003780
# 4       0.039939      0.002046         0.003883        0.003808
# 5       0.041810      0.001274         0.005982        0.005202
# 6       0.049697      0.003195         0.003696        0.004350
# 7       0.052255      0.004580         0.004633        0.004618
# 8       0.043621      0.010831         0.004818        0.006609
#
#   param_n_estimators param_objective param_seed  \
# 0                 10      reg:linear         10
# 1                 10      reg:linear         20
# 2                 10      reg:linear         30
# 3                 20      reg:linear         10
# 4                 20      reg:linear         20
# 5                 20      reg:linear         30
# 6                 30      reg:linear         10
# 7                 30      reg:linear         20
# 8                 30      reg:linear         30
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 10, 'objective': 'reg:linear'...           0.865185
# 1  {'n_estimators': 10, 'objective': 'reg:linear'...           0.865185
# 2  {'n_estimators': 10, 'objective': 'reg:linear'...           0.865185
# 3  {'n_estimators': 20, 'objective': 'reg:linear'...           0.854335
# 4  {'n_estimators': 20, 'objective': 'reg:linear'...           0.854335
# 5  {'n_estimators': 20, 'objective': 'reg:linear'...           0.854335
# 6  {'n_estimators': 30, 'objective': 'reg:linear'...           0.846690
# 7  {'n_estimators': 30, 'objective': 'reg:linear'...           0.846690
# 8  {'n_estimators': 30, 'objective': 'reg:linear'...           0.846690
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.797683           0.874604           0.837803           0.862310
# 1           0.797683           0.874604           0.837803           0.862310
# 2           0.797683           0.874604           0.837803           0.862310
# 3           0.786175           0.871105           0.833108           0.850118
# 4           0.786175           0.871105           0.833108           0.850118
# 5           0.786175           0.871105           0.833108           0.850118
# 6           0.769403           0.863516           0.830113           0.842325
# 7           0.769403           0.863516           0.830113           0.842325
# 8           0.769403           0.863516           0.830113           0.842325
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.847517        0.027722                1
# 1         0.847517        0.027722                1
# 2         0.847517        0.027722                1
# 3         0.838968        0.029033                4
# 4         0.838968        0.029033                4
# 5         0.838968        0.029033                4
# 6         0.830410        0.032326                7
# 7         0.830410        0.032326                7
# 8         0.830410        0.032326                7

# %%
Age_input=float(input("Age:"))
BMI_input=float(input("BMI:"))
Children_input=float(input("Children:"))
Sex_male_input=int(input("Sex Male 0 or 1:"))
Smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 20
# BMI: 20
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[Age_input,BMI_input,Children_input,Sex_male_input,Smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[15519.056]
